# %%
#==================== We set product parameters to download ====================
import os, re

# You can create a list of number strings by using: [f"{i:02}" for i in range(13)]
destination_path = '.\\GOESimages\\'
bucket = 'noaa-goes16'
satellite = bucket[re.search('noaa-',bucket).end():]
product=['ABI-L2-DSRF','ABI-L2-ACMF','ABI-L2-TPWF','ABI-L2-RRQPEF','ABI-L2-LSTF'] # Product to select
channel=['C01','C02','C03'] # Number of band to select from 'C01' to 'C16'
# Select a product and channel to process
selected_product = product[-1]
domain = selected_product[-1]
selected_channel = channel[0]

from goespy.Downloader import ABI_Downloader
import xarray as xr
#==================== Setting up time reference variables ====================
from datetime import datetime, timedelta
import pytz, time
utc = pytz.timezone('UTC') # UTC timezone
utcm5 = pytz.timezone('America/Lima') # UTC-5 timezone

import numpy as np
PeruLimits_deg = [-85, -67.5, -20.5, 1.0] # Define the coordinates of the bounding box around Peru

#==================== Creating georeferenced variables ====================
import geopandas as gpd
from shapely.geometry import Polygon
import cartopy.feature as cfeature
# Add coastlines feature
coastlines_feature = cfeature.NaturalEarthFeature(
    category='physical',
    name='coastline',
    scale='50m',
    edgecolor='black',
    facecolor='none')
# Add country boundaries feature
countries_feature = cfeature.NaturalEarthFeature(
    category='cultural',
    name='admin_0_countries',
    scale='50m',
    edgecolor='black',
    facecolor='none')
# Create the polygon representing the bounding box
peru_bbox = Polygon([(PeruLimits_deg[0], PeruLimits_deg[2]), (PeruLimits_deg[1], PeruLimits_deg[2]), (PeruLimits_deg[1], PeruLimits_deg[3]), (PeruLimits_deg[0], PeruLimits_deg[3])])
# gdf_countries = gpd.read_file("./Boundaries/ne_10m_admin_0_countries/ne_10m_admin_0_countries.shp")
gdf_maritime = gpd.read_file("./Boundaries/World_EEZ_v11_20191118/eez_v11.shp",mask=peru_bbox)
gdf_states = gpd.read_file("./Boundaries/ne_10m_admin_1_states_provinces/ne_10m_admin_1_states_provinces.shp",mask=peru_bbox)
# Filter the GeoDataFrame to keep only rows where adm1_code matches "PER"
gdf_peru_land = gdf_states[gdf_states["adm1_code"].str[:3] == "PER"]
gdf_peru_sea = gdf_maritime[gdf_maritime["TERRITORY1"] == "Peru"].iloc[[1]]
# gdf_maritime = gdf_maritime[gdf_maritime["TERRITORY1"] != "Peru"]

import cartopy.crs as ccrs
import matplotlib.pyplot as plt

import goes2go as g2g

import sys
sys.path.append('./Local2Drive/')
import ToGoogleDrive as togd
import IPython.display as display
# Set the time interval for clearing the output
time_interval = timedelta(hours=1)
start_time = datetime.now()

# Define the RGB values for your colormap
import matplotlib.colors as mcolors
rgb_values = [
    [255, 255, 255],
    [127, 127, 127],
    [0, 200, 255],
    [0, 163, 255],
    [0, 82, 255],
    [0, 0, 200],
    [150, 255, 150],
    [50, 200, 50],
    [0, 130, 0],
    [255, 255, 0],
    [170, 170, 0],
    [255, 127, 0],
    [200, 70, 70],
    [255, 160, 160],
    [255, 0, 0],
    [157, 0, 157],
    [0, 0, 0],
    [222, 222, 222]]
# Normalize the RGB values to the range [0, 1]
norm = mcolors.Normalize(vmin=0, vmax=len(rgb_values) - 1)
colors = [tuple(rgb / 255.0 for rgb in rgb_value) for rgb_value in rgb_values]
# Create the colormap
rainfall_cmap = mcolors.ListedColormap(colors)
colormaps = {'ABI-L2-DSRF':'turbo','ABI-L2-ACMF':'GnBu','ABI-L2-TPWF':'terrain_r','ABI-L2-LSTF':'jet'}
colormaps['ABI-L2-RRQPEF'] = rainfall_cmap

while True:
    TodaysDate = datetime.now(utc).strftime('%Y-%m-%d %H:%M:%S %Z')
    day, month, year = TodaysDate[8:10], TodaysDate[5:7], TodaysDate[:4]
    hour, minute, seconds = TodaysDate[11:13], TodaysDate[14:16], TodaysDate[17:20]
    print("============================================================")
    print("Current time is: {}".format(TodaysDate))
        
    #==================== Building the path to the folder for file storage ====================
    ABI = ABI_Downloader(destination_path,bucket,year,month,day,hour,product,selected_channel)
    for selected_product in product:
        FilePath = os.path.join(destination_path, satellite, year, month, day, selected_product, hour)
        if (selected_product[:-1] == "ABI-L1b-Rad") or (selected_product[:-1] == "ABI-L2-CMIP"):
            FilePath = os.path.join(FilePath,selected_channel)
        print("\nProcessing files in path: {}".format(FilePath))
        
        if (not os.path.exists(FilePath)):
            print("Directory does not exist. Creating new one...") 
            os.makedirs(FilePath)
        old_files = os.listdir(FilePath)
        old_nc_files = set([file for file in old_files if file.endswith('.nc')])
        are_there_old_filenames = (len(old_nc_files) > 0)
        
        # new_files = os.listdir(FilePath)
        # new_nc_files = set([file for file in new_files if file.endswith('.nc')])
        # new_filenames = list(new_nc_files - old_nc_files)
        # are_there_new_filenames = (len(new_filenames) > 0)
        
        # to_plot_existing_images = (not image_exists) and are_there_old_filenames
        if (are_there_old_filenames):
            print("GOES datasets available:")
            display.display(old_nc_files)
            # if(to_plot_existing_images): 
            #     print("Old files detected, but there are no images saved. Creating them...")
            #     filenames = old_nc_files
            # elif(are_there_new_filenames): 
            #     print("\nNew files detected!:")
            #     filenames = new_filenames
            
            for f in old_nc_files: 
                print("Working with file: {}".format(f))
                # Building image name format
                start_date_str = f.split("_s")[1][:13]
                start_date = datetime.strptime(start_date_str, "%Y%j%H%M%S").strftime('%Y-%m-%d %H:%M:%S')
                img_year, img_month, img_day = start_date[:4], start_date[5:7], start_date[8:10]
                img_hour, img_minute, img_seconds = start_date[11:13], start_date[14:16], start_date[17:20]
                if ( selected_product[:-1] == "ABI-L1b-Rad") or (selected_product[:-1] == "ABI-L2-CMIP"):
                    ImageName = satellite +'_'+ img_year +'_'+ img_month +'_'+ img_day +'_'+ selected_product.split('-')[-1] +'_'+ selected_channel +'_'+ img_hour +'_'+ img_minute + '.png'
                else: ImageName = satellite +'_'+ img_year +'_'+ img_month +'_'+ img_day +'_'+ selected_product.split('-')[-1] +'_'+ img_hour +'_'+ img_minute + '.png'
                FullImagePath = os.path.join(FilePath, ImageName)
                does_image_exist = os.path.exists(FullImagePath)
                if(not does_image_exist):
                    print("File image not found, creating one...")
                    FullFilePath = os.path.join(FilePath,f)
                    #==================== Read the dataset and its metadata ====================
                    data = xr.open_dataset(FullFilePath, engine='netcdf4')
                    if ('lon' in data.coords) and ('lat' in data.coords): coords = "lonlat"
                    elif ('x' in data.coords) and ('y' in data.coords): coords = "xy"

                    #==================== Getting information from GOES image dataset ====================
                    varname = list(data.data_vars.keys())[0]
                    ImgTime = data.t.values
                    ImgTime = utc.localize(datetime.utcfromtimestamp(ImgTime.tolist()//10**9))
                    ImgTime -= timedelta(hours=5)
                    minute = str(ImgTime.minute).zfill(2)
                    str_ImgTime = ImgTime.strftime('%Y-%m-%d %H:%M %Z-5')
                    spatial_res = data.attrs["spatial_resolution"].split()[0]
                    # spatial_res = float(re.findall('\d+',spatial_res)[0])
                    LonCenter = data.geospatial_lat_lon_extent.geospatial_lon_center
                    LatCenter = data.geospatial_lat_lon_extent.geospatial_lat_center
                    LonLimits = np.array([data.geospatial_lat_lon_extent.geospatial_westbound_longitude, data.geospatial_lat_lon_extent.geospatial_eastbound_longitude])
                    LatLimits = np.array([data.geospatial_lat_lon_extent.geospatial_southbound_latitude, data.geospatial_lat_lon_extent.geospatial_northbound_latitude])
                    imgExtention = [LonLimits[0], LonLimits[1], LatLimits[0], LatLimits[1]]

                    #==================== Defining projections ====================
                    map_proj_ortho = ccrs.Orthographic(central_longitude=LonCenter, central_latitude=LatCenter), "Orthographic"
                    map_proj_pc = ccrs.PlateCarree(), "PlateCarree projection"
                    if (coords == "lonlat"):
                        lon = data.lon.values
                        lat = data.lat.values
                        gproj = data['goes_lat_lon_projection']
                        map_proj_geos = ccrs.Geostationary(
                                    central_longitude=LonCenter,
                                    satellite_height=data.nominal_satellite_height.values*1000,
                                    sweep_axis='x',
                                    globe=ccrs.Globe(ellipse='sphere', # 'sphere', 'WGS84'
                                                semimajor_axis=gproj.semi_major_axis, 
                                                semiminor_axis=gproj.semi_minor_axis)), "Geostationary projection"
                        map_proj_src = map_proj_pc
                        map_proj_dst = map_proj_geos
                    elif (coords == "xy"):
                        gproj = data['goes_imager_projection']
                        map_proj_geos = ccrs.Geostationary(
                                        central_longitude=LonCenter,
                                        satellite_height=data.nominal_satellite_height.values*1000,
                                        sweep_axis=gproj.sweep_angle_axis,
                                        globe=ccrs.Globe(ellipse='sphere', # 'sphere', 'WGS84'
                                                        semimajor_axis=gproj.semi_major_axis, 
                                                        semiminor_axis=gproj.semi_minor_axis)), "Geostationary projection"
                        map_proj_src = map_proj_geos
                        map_proj_dst = map_proj_pc
                    product_cmap = colormaps[selected_product]
                    #==================== Plotting the product ====================
                    if(coords == "xy"):
                        fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(projection=map_proj_dst[0]))
                        ax.set_extent(PeruLimits_deg)
                        # im = ax.imshow(transformed_data, origin='lower', transform=map_proj_dst[0], extent=extent_deg, cmap='turbo')
                        im = ax.imshow(data[varname].values, transform=map_proj_src[0], cmap=product_cmap)
                        cbar = plt.colorbar(im,ax=ax, orientation='horizontal', shrink=0.5, pad=0.05)
                        units_latex = re.sub(r'(\w)(-)(\d)', r'\1^{-\3}', data[varname].units)
                        if ( selected_product[:-1] == "ABI-L1b-Rad") or (selected_product[:-1] == "ABI-L2-CMIP"):
                            cbar.set_label(r"{} $({})$, band={}".format(data.title,units_latex,selected_channel))
                        else:
                            cbar.set_label(r"{} $({})$".format(data.title,units_latex))
                        ax.add_feature(coastlines_feature, linewidth=0.75)
                        ax.add_feature(countries_feature, linewidth=0.75)
                        ax.add_geometries(gdf_peru_land['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor='black', linewidth=0.75)
                        ax.add_geometries(gdf_peru_sea['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor='black', linewidth=0.75)
                        ax.gridlines(draw_labels=True,lw=0.75,color='k',alpha=0.7,ls='--')
                        ax.set_title("GOES Image, Platform: {}, Geographic coverage: {}\n Spatial resolution: {}, {}".format(data.platform_ID,data.scene_id,spatial_res,str_ImgTime))
                    elif(coords == "lonlat"):
                        fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(projection=map_proj_src[0]))
                        ax.set_extent(PeruLimits_deg)
                        im = ax.pcolormesh(lon,lat,data[varname].values,cmap=product_cmap,transform=map_proj_src[0])
                        cbar = plt.colorbar(im,ax=ax, orientation='horizontal', shrink=0.5, pad=0.05)
                        units_latex = re.sub(r'(\w)(-)(\d)', r'\1^{-\3}', data[varname].units)
                        if ( selected_product[:-1] == "ABI-L1b-Rad") or (selected_product[:-1] == "ABI-L2-CMIP"):
                            cbar.set_label(r"{} $({})$, band={}".format(data.title,units_latex,selected_channel))
                        else:
                            cbar.set_label(r"{} $({})$".format(data.title,units_latex))
                        ax.add_feature(coastlines_feature, linewidth=0.75)
                        ax.add_feature(countries_feature, linewidth=0.75)
                        ax.add_geometries(gdf_peru_land['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor='black', linewidth=0.75)
                        ax.add_geometries(gdf_peru_sea['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor='black', linewidth=0.75)
                        ax.gridlines(draw_labels=True,lw=0.75,color='k',alpha=0.7,ls='--')
                        ax.set_title("GOES Image, Platform: {}, Geographic coverage: {}\n Spatial resolution: {}, {}".format(data.platform_ID,data.scene_id,spatial_res,str_ImgTime))
                    plt.savefig(FullImagePath,dpi=300,bbox_inches='tight')
                    plt.show()
                    print("Image '{}' saved in '{}'".format(ImageName,FilePath))
            print("All the files have been processed.")
        else: 
            print("No old files detected.") 
            
    data = g2g.data.goes_latest(satellite='noaa-goes16', product='ABI', domain='F', download=True, save_dir=destination_path)
    ImgTime = data.t.values
    ImgTime = utc.localize(datetime.utcfromtimestamp(ImgTime.tolist()//10**9))
    ImgTime -= timedelta(hours=5)
    minute = str(ImgTime.minute).zfill(2)
    str_ImgTime = ImgTime.strftime('%Y-%m-%d %H:%M %Z-5')
    spatial_res = data.attrs["spatial_resolution"].split()[0]
    # Building Image name format
    img_year, img_month, img_day = str_ImgTime[:4], str_ImgTime[5:7], str_ImgTime[8:10]
    img_hour, img_minute, img_seconds = str_ImgTime[11:13], str_ImgTime[14:16], str_ImgTime[17:20]
    RGBImageName = satellite +'_'+ img_year +'_'+ img_month +'_'+ img_day +'_TrueColor_'+ img_hour +'_'+ img_minute + '.png'
    RGBImagePath = os.path.join(destination_path,'RGBImages',RGBImageName)
    # Plotting TrueColor images
    print("Plotting TrueColor image...")
    map_proj_pc = ccrs.PlateCarree(), "PlateCarree projection"
    fig, ax = plt.subplots(figsize=(10, 8), subplot_kw=dict(projection=data.rgb.crs))
    ax.set_extent(PeruLimits_deg)
    ax.imshow(data.rgb.TrueColor(), **data.rgb.imshow_kwargs)
    edgecolor = 'darkgray'
    ax.add_feature(coastlines_feature, linewidth=0.75, edgecolor=edgecolor)
    ax.add_feature(countries_feature, linewidth=0.75, edgecolor=edgecolor)
    ax.add_geometries(gdf_peru_land['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor=edgecolor, linewidth=0.75)
    ax.add_geometries(gdf_peru_sea['geometry'], crs=map_proj_pc[0], facecolor='none', edgecolor=edgecolor, linewidth=0.75)
    ax.gridlines(draw_labels=True, lw=0.75, color='lightgray', alpha=0.7, ls='--')
    ax.set_title("GOES Image, Platform: {}, Geographic coverage: {}\n Spatial resolution: {}, {}".format(data.platform_ID,data.scene_id,spatial_res,str_ImgTime))
    ax.axis('off')
    # fig.set_facecolor('k')
    plt.savefig(RGBImagePath,dpi=300,bbox_inches='tight')
    plt.show()
    
    #==================== Uploading images to boogle Drive ====================
    if(ImgTime.hour>5 and ImgTime.hour <19):
        GOESimages_folder_id = "1MuqlbKZDyh_Ztlz9rMFx6hdAFgOdRuoD"
        togd.subir_archivo(RGBImagePath, GOESimages_folder_id)
    else: print("It's night, the true color image is not uploaded to Google Drive")
    
    # Check if it's time to clear the output
    elapsed_time = datetime.now() - start_time
    if elapsed_time >= time_interval:
        # Clear the output
        display.clear_output(wait=True)
        # Reset the start time
        start_time = datetime.now()
        
    total_remaining_seconds = (10 - (int(minute) % 10)) * 60 - int(seconds)
    remaining_minutes = total_remaining_seconds // 60
    # remaining_seconds = total_remaining_seconds % 60
    print("Waiting {} minutes for the next file upload".format(remaining_minutes + 3))
    time.sleep(total_remaining_seconds + 3*60)
# Out:
# Waiting 7 minutes for the next file upload
# ============================================================
# Current time is: 2023-07-15 02:06:39 UTC
# Downloading... the product ABI-L2-DSRF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-ACMF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-TPWF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-RRQPEF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-LSTF
# Downloading dataset to... 02 UTC
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-DSRF\02
# Directory does not exist. Creating new one...
# No old files detected.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02
# Directory does not exist. Creating new one...
# No old files detected.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02
# Directory does not exist. Creating new one...
# No old files detected.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02
# Directory does not exist. Creating new one...
# No old files detected.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-LSTF\02
# Directory does not exist. Creating new one...
# No old files detected.
# 📦 Finished downloading [1] files to [GOESimages\noaa-goes16\ABI-L2-MCMIPF].
# 📚 Finished reading [1] files into xarray.Dataset.
# Plotting TrueColor image...
# It's night, the true color image is not uploaded to Google Drive
# Waiting 7 minutes for the next file upload
# ============================================================
# Current time is: 2023-07-15 02:15:54 UTC
# Downloading... the product ABI-L2-DSRF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-ACMF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc: [##########] 100%  24.755322 MB/24.755322 MBDownloading... the product ABI-L2-TPWF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc: [##########] 100%  1.122002 MB/1.122002 MBDownloading... the product ABI-L2-RRQPEF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc: [##########] 100%  1.667823 MB/1.667823 MBDownloading... the product ABI-L2-LSTF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc: [##########] 100%  0.670398 MB/0.670398 MB
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-DSRF\02
# No old files detected.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02
# GOES datasets available:
# {'OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc'}
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_ACMF_02_00.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02'
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02
# GOES datasets available:
# {'OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc'}
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_TPWF_02_00.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02'
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02
# GOES datasets available:
# {'OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc'}
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_RRQPEF_02_00.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02'
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-LSTF\02
# GOES datasets available:
# {'OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc'}
# Working with file: OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_LSTF_02_00.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-LSTF\02'
# All the files have been processed.
# 📦 Finished downloading [1] files to [GOESimages\noaa-goes16\ABI-L2-MCMIPF].
# 📚 Finished reading [1] files into xarray.Dataset.
# Plotting TrueColor image...
# It's night, the true color image is not uploaded to Google Drive
# Waiting 7 minutes for the next file upload
# ============================================================
# Current time is: 2023-07-15 02:24:44 UTC
# Downloading... the product ABI-L2-DSRF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-DSRF-M6_G16_s20231960200208_e20231960209516_c20231960221397.nc: [##########] 100%  0.111066 MB/0.111066 MBDownloading... the product ABI-L2-ACMF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-ACMF-M6_G16_s20231960210208_e20231960219516_c20231960220348.nc: [##########] 100%  24.68594 MB/24.68594 MBDownloading... the product ABI-L2-TPWF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-TPWF-M6_G16_s20231960210208_e20231960219516_c20231960221451.nc: [##########] 100%  1.122698 MB/1.122698 MBDownloading... the product ABI-L2-RRQPEF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-RRQPEF-M6_G16_s20231960210208_e20231960219516_c20231960219599.nc: [##########] 100%  1.660979 MB/1.660979 MBDownloading... the product ABI-L2-LSTF
# Downloading dataset to... 02 UTC
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-DSRF\02
# GOES datasets available:
# {'OR_ABI-L2-DSRF-M6_G16_s20231960200208_e20231960209516_c20231960221397.nc'}
# Working with file: OR_ABI-L2-DSRF-M6_G16_s20231960200208_e20231960209516_c20231960221397.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_DSRF_02_00.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-DSRF\02'
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02
# GOES datasets available:
# {'OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc',
#  'OR_ABI-L2-ACMF-M6_G16_s20231960210208_e20231960219516_c20231960220348.nc'}
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960210208_e20231960219516_c20231960220348.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_ACMF_02_10.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02'
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02
# GOES datasets available:
# {'OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc',
#  'OR_ABI-L2-TPWF-M6_G16_s20231960210208_e20231960219516_c20231960221451.nc'}
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960210208_e20231960219516_c20231960221451.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_TPWF_02_10.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02'
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02
# GOES datasets available:
# {'OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc',
#  'OR_ABI-L2-RRQPEF-M6_G16_s20231960210208_e20231960219516_c20231960219599.nc'}
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960210208_e20231960219516_c20231960219599.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_RRQPEF_02_10.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02'
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-LSTF\02
# GOES datasets available:
# {'OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc'}
# Working with file: OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc
# All the files have been processed.
# 📦 Finished downloading [1] files to [GOESimages\noaa-goes16\ABI-L2-MCMIPF].
# 📚 Finished reading [1] files into xarray.Dataset.
# Plotting TrueColor image...
# It's night, the true color image is not uploaded to Google Drive
# Waiting 7 minutes for the next file upload
# ============================================================
# Current time is: 2023-07-15 02:33:39 UTC
# Downloading... the product ABI-L2-DSRF
# Downloading dataset to... 02 UTC
# Downloading... the product ABI-L2-ACMF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-ACMF-M6_G16_s20231960220208_e20231960229516_c20231960230305.nc: [##########] 100%  24.641779 MB/24.641779 MBDownloading... the product ABI-L2-TPWF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-TPWF-M6_G16_s20231960220208_e20231960229516_c20231960231033.nc: [##########] 100%  1.122444 MB/1.122444 MBDownloading... the product ABI-L2-RRQPEF
# Downloading dataset to... 02 UTC
# OR_ABI-L2-RRQPEF-M6_G16_s20231960220208_e20231960229516_c20231960230003.nc: [##########] 100%  1.649842 MB/1.649842 MBDownloading... the product ABI-L2-LSTF
# Downloading dataset to... 02 UTC
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-DSRF\02
# GOES datasets available:
# {'OR_ABI-L2-DSRF-M6_G16_s20231960200208_e20231960209516_c20231960221397.nc'}
# Working with file: OR_ABI-L2-DSRF-M6_G16_s20231960200208_e20231960209516_c20231960221397.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02
# GOES datasets available:
# {'OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc',
#  'OR_ABI-L2-ACMF-M6_G16_s20231960210208_e20231960219516_c20231960220348.nc',
#  'OR_ABI-L2-ACMF-M6_G16_s20231960220208_e20231960229516_c20231960230305.nc'}
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960210208_e20231960219516_c20231960220348.nc
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960220208_e20231960229516_c20231960230305.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_ACMF_02_20.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-ACMF\02'
# Working with file: OR_ABI-L2-ACMF-M6_G16_s20231960200208_e20231960209516_c20231960210333.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02
# GOES datasets available:
# {'OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc',
#  'OR_ABI-L2-TPWF-M6_G16_s20231960210208_e20231960219516_c20231960221451.nc',
#  'OR_ABI-L2-TPWF-M6_G16_s20231960220208_e20231960229516_c20231960231033.nc'}
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960220208_e20231960229516_c20231960231033.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_TPWF_02_20.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-TPWF\02'
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960210208_e20231960219516_c20231960221451.nc
# Working with file: OR_ABI-L2-TPWF-M6_G16_s20231960200208_e20231960209516_c20231960211089.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02
# GOES datasets available:
# {'OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc',
#  'OR_ABI-L2-RRQPEF-M6_G16_s20231960210208_e20231960219516_c20231960219599.nc',
#  'OR_ABI-L2-RRQPEF-M6_G16_s20231960220208_e20231960229516_c20231960230003.nc'}
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960210208_e20231960219516_c20231960219599.nc
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960220208_e20231960229516_c20231960230003.nc
# File image not found, creating one...
# Image 'goes16_2023_07_15_RRQPEF_02_20.png' saved in '.\GOESimages\goes16\2023\07\15\ABI-L2-RRQPEF\02'
# Working with file: OR_ABI-L2-RRQPEF-M6_G16_s20231960200208_e20231960209516_c20231960210015.nc
# All the files have been processed.
#
# Processing files in path: .\GOESimages\goes16\2023\07\15\ABI-L2-LSTF\02
# GOES datasets available:
# {'OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc'}
# Working with file: OR_ABI-L2-LSTF-M6_G16_s20231960200208_e20231960209516_c20231960210412.nc
# All the files have been processed.
# 📦 Finished downloading [1] files to [GOESimages\noaa-goes16\ABI-L2-MCMIPF].
# 📚 Finished reading [1] files into xarray.Dataset.
# Plotting TrueColor image...
# It's night, the true color image is not uploaded to Google Drive
# Waiting 7 minutes for the next file upload
